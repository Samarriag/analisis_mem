# %% [markdown]
# <a href="https://colab.research.google.com/github/Samarriag/analisis_mem/blob/main/NODES_CENACE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The mexican electricity system is controled by CENACE.
# The electricity nacional system (SEN) is made up of 3 interconnected systems: National Interconected System (SIN), Baja Califoria System (BCA) & Baja California Sur System (BCS).
# There are more than 2,500 nodes in the SEN that are located within the 8 control zones: central, west, east, northeast, northwest, BCA, BCS, peninsular

# %%
import pandas as pd

# %%
catalogue = pd.read_excel('https://github.com/Samarriag/analisis_mem/raw/main/Nodos2022.xlsx')
catalogue
# Out:
#      SISTEMA CENTRO DE CONTROL REGIONAL  ... MUNICIPIO (INEGI) REGION DE TRANSMISION
# 0        BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# 1        BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# 2        BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# 3        BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# 4        BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# ...      ...                        ...  ...               ...                   ...
# 2535     SIN                 PENINSULAR  ...             MOTUL                MERIDA
# 2536     SIN                 PENINSULAR  ...           MAXCANU                MERIDA
# 2537     SIN                 PENINSULAR  ...             TICUL                MERIDA
# 2538     SIN                 PENINSULAR  ...             TEKAX                MERIDA
# ...

# %%
catalogue.columns
# Out:
# Index(['SISTEMA', 'CENTRO DE CONTROL REGIONAL', 'ZONA DE CARGA', 'CLAVE',
#        'NOMBRE', 'NIVEL DE TENSIÓN (kV)', 'DIRECTAMENTE MODELADA',
#        'INDIRECTAMENTE MODELADA', 'DIRECTAMENTE MODELADA.1',
#        'INDIRECTAMENTE MODELADA.1', 'ZONA DE OPERACIÓN DE TRANSMISIÓN',
#        'GERENCIA REGIONAL DE TRANSMISIÓN', 'ZONA DE DISTRIBUCIÓN',
#        'GERENCIA DIVISIONAL DE DISTRIBUCIÓN',
#        'CLAVE DE ENTIDAD FEDERATIVA (INEGI)', 'ENTIDAD FEDERATIVA (INEGI)',
#        'CLAVE DE MUNICIPIO (INEGI)', 'MUNICIPIO (INEGI)',
#        'REGION DE TRANSMISION'],
#       dtype='object')

# %%
catalogue.head()
# Out:
#   SISTEMA CENTRO DE CONTROL REGIONAL  ... MUNICIPIO (INEGI) REGION DE TRANSMISION
# 0     BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# 1     BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# 2     BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# 3     BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
# 4     BCA            BAJA CALIFORNIA  ...          ENSENADA              ENSENADA
#
# [5 rows x 19 columns]

# %%
catalogue.tail()
# Out:
#      SISTEMA CENTRO DE CONTROL REGIONAL  ... MUNICIPIO (INEGI) REGION DE TRANSMISION
# 2535     SIN                 PENINSULAR  ...             MOTUL                MERIDA
# 2536     SIN                 PENINSULAR  ...           MAXCANU                MERIDA
# 2537     SIN                 PENINSULAR  ...             TICUL                MERIDA
# 2538     SIN                 PENINSULAR  ...             TEKAX                MERIDA
# 2539     SIN                 PENINSULAR  ...         TIXMEHUAC                MERIDA
#
# [5 rows x 19 columns]

# %%
catalogue.NOMBRE
# Out:
# 0       Acueducto La Mision
# 1            Aguas Ensenada
# 2                    Cipres
# 3                     Cemex
# 4                   Colonet
#                ...
# 2535                 Kambul
# 2536                Maxcanu
# 2537                  Ticul
# 2538              Tekax Dos
# 2539              Tixmehuac
# Name: NOMBRE, Length: 2540, dtype: object

# %%
catalogue["ZONA DE CARGA"]
# Out:
# 0       ENSENADA
# 1       ENSENADA
# 2       ENSENADA
# 3       ENSENADA
# 4       ENSENADA
#           ...
# 2535       TICUL
# 2536       TICUL
# 2537       TICUL
# 2538       TICUL
# 2539       TICUL
# Name: ZONA DE CARGA, Length: 2540, dtype: object

# %% [markdown]
# Let's start filtering data:

# %%
catalogue["ZONA DE CARGA"].unique()
# Out:
# array(['ENSENADA', 'MEXICALI', 'SANLUIS', 'TIJUANA', 'No Aplica',
#        'CONSTITUCION', 'LA PAZ', 'LOS CABOS', 'CENTRO ORIENTE',
#        'CENTRO SUR', 'LAZARO CARDENAS', 'VDM CENTRO', 'VDM NORTE',
#        'VDM SUR', 'HUASTECA', 'HUEJUTLA', 'MATAMOROS', 'MONCLOVA',
#        'MONTEMORELOS', 'MONTERREY', 'NUEVO LAREDO', 'PIEDRAS NEGRAS',
#        'REYNOSA', 'SABINAS', 'SALTILLO', 'TAMPICO', 'VICTORIA', 'CABORCA',
#        'CULIACAN', 'GUASAVE', 'GUAYMAS', 'HERMOSILLO', 'LOS MOCHIS',
#        'MAZATLAN', 'NAVOJOA', 'NOGALES', 'OBREGON', 'CAMARGO',
#        'CASAS GRANDES', 'CHIHUAHUA', 'CUAUHTEMOC', 'DURANGO', 'JUAREZ',
#        'LAGUNA', 'AGUASCALIENTES', 'APATZINGAN', 'CELAYA', 'CIENEGA',
#        'COLIMA', 'FRESNILLO', 'GUADALAJARA', 'IRAPUATO', 'IXMIQUILPAN',
#        'JIQUILPAN', 'LEON', 'LOS ALTOS', 'MANZANILLO', 'MATEHUALA',
#        'MINAS', 'MORELIA', 'QUERETARO', 'SALVATIERRA', 'SAN JUAN DEL RIO',
#        'SAN LUIS POTOSI', 'TEPIC VALLARTA', 'URUAPAN', 'ZACAPU',
# ...

# %% [markdown]
# How many control zones are in the SEN?

# %%
len(catalogue["ZONA DE CARGA"].unique())-1
# Out:
# 108

# %% [markdown]
# Minus one because there is a control zone called: "No aplica" (does not apply); this is because the virtual nodes (import-export nodes). There are 3 links with ERCOT in the Northeast, 2 links with CAISO in the BCA, and 1 link in the South with Guatemala. Those intended for commercial operations. (https://www.cenace.gob.mx/Docs/14_REGLAS/Manuales/Manual%20de%20Importaciones%20y%20Exportaciones%20[DOF%2011-12-17].pdf)

# %%
catalogue.loc[catalogue["ZONA DE CARGA"]=='No Aplica']
# Out:
#     SISTEMA CENTRO DE CONTROL REGIONAL  ... MUNICIPIO (INEGI) REGION DE TRANSMISION
# 111     BCA                  No Aplica  ...         No Aplica             No Aplica
# 112     BCA                  No Aplica  ...         No Aplica             No Aplica
# 405     SIN                  No Aplica  ...         No Aplica             No Aplica
# 406     SIN                  No Aplica  ...         No Aplica             No Aplica
# 407     SIN                  No Aplica  ...         No Aplica             No Aplica
# 408     SIN                  No Aplica  ...         No Aplica             No Aplica
# 409     SIN                  No Aplica  ...         No Aplica             No Aplica
#
# [7 rows x 19 columns]

# %% [markdown]
# Which are the voltage levels that are handled in the substations of Mexico?

# %%
catalogue['NIVEL DE TENSIÓN (kV)'].unique()
# Out:
# array([115. , 230. ,  69. , 161. ,  85. , 400. , 138. ,  34.5])

# %%
len(catalogue['NIVEL DE TENSIÓN (kV)'].unique())
# Out:
# 8

# %% [markdown]
# Where are the 400 kV substation?

# %%
catalogue=pd.read_excel('https://github.com/Samarriag/analisis_mem/raw/main/Nodos2022.xlsx', index_col='CLAVE')
Nodes400kV= catalogue.loc[catalogue['NIVEL DE TENSIÓN (kV)']==400, ['ZONA DE CARGA','REGION DE TRANSMISION']]
Nodes400kV
# Out:
#              ZONA DE CARGA REGION DE TRANSMISION
# CLAVE
# 01TUL-400   CENTRO ORIENTE               CENTRAL
# 01LCP-400  LAZARO CARDENAS               CENTRAL
# 01PIT-400  LAZARO CARDENAS               CENTRAL
# 01VMA-400        VDM NORTE               CENTRAL
# 06AHM-400         MONCLOVA             MONTERREY
# 06SCP-400     MONTEMORELOS              SALTILLO
# 06CDU-400        MONTERREY             MONTERREY
# 06ESC-400        MONTERREY             MONTERREY
# 06FAI-400        MONTERREY             MONTERREY
# 06HUO-400        MONTERREY             MONTERREY
# 06HYM-400        MONTERREY             MONTERREY
# 06PGE-400        MONTERREY             MONTERREY
# 06TRQ-400        MONTERREY             MONTERREY
# 06CBD-400   PIEDRAS NEGRAS         RIO ESCONDIDO
# 06REC-400   PIEDRAS NEGRAS         RIO ESCONDIDO
# 06AER-400          REYNOSA               REYNOSA
# 06ATP-400          REYNOSA               REYNOSA
# 06RAP-400         SALTILLO              SALTILLO
# ...

# %%
len(Nodes400kV)
# Out:
# 49

# %%
catalogue['ZONA DE CARGA'].value_counts()
# Out:
# MONTERREY          119
# SAN LUIS POTOSI     73
# VDM NORTE           72
# GUADALAJARA         70
# QUERETARO           68
#                   ...
# JIQUILPAN            4
# CARMEN               4
# CUERNAVACA           3
# SABINAS              3
# HUEJUTLA             2
# Name: ZONA DE CARGA, Length: 109, dtype: int64

# %% [markdown]
# I want to know how many substations are per voltage level in every control zone, please.

# %%
catalogue_voltage= catalogue.groupby(['ZONA DE CARGA', 'NIVEL DE TENSIÓN (kV)'])['NIVEL DE TENSIÓN (kV)'].count()
catalogue_voltage
# Out:
# ZONA DE CARGA   NIVEL DE TENSIÓN (kV)
# ACAPULCO        69.0                      1
#                 115.0                    27
# AGUASCALIENTES  115.0                    40
#                 230.0                     6
#                 400.0                     2
#                                          ..
# ZACATECAS       230.0                     1
#                 400.0                     3
# ZAMORA          115.0                    28
# ZAPOTLAN        115.0                     8
# ZIHUATANEJO     115.0                    10
# Name: NIVEL DE TENSIÓN (kV), Length: 212, dtype: int64
